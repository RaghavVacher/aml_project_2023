# %%
import numpy as np
import matplotlib.pyplot as plt
from nilearn import plotting

# %%
lh1 = np.load('./algonauts/subj01/training_split/training_fmri/lh_training_fmri.npy')
rh1 = lh1 = np.load('./algonauts/subj01/training_split/training_fmri/rh_training_fmri.npy')

# %%
# Assuming 'fmri_data' is your 3D fMRI data
plotting.plot_epi(rh1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/aleksygalkowski/Documents/Projects/ucph/social-data-science/2023 sem 3/aml-itu/aml_project_2023/data/explore_data.ipynb Cell 5 line <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/aleksygalkowski/Documents/Projects/ucph/social-data-science/2023%20sem%203/aml-itu/aml_project_2023/data/explore_data.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> num_slices = lh1.shape[1]  # Get the number of slices in the data
#       <a href='vscode-notebook-cell:/Users/aleksygalkowski/Documents/Projects/ucph/social-data-science/2023%20sem%203/aml-itu/aml_project_2023/data/explore_data.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> # Display multiple slices using subplots
# ...
