# %%
import torch
import matplotlib.pyplot as plt

# load a trained .pt file for analysis
model = torch.load('resnet50epochs.pt', map_location=torch.device('cpu'))
# print keys of model
print(model['history']['val_loss'])
#from model['history'] create a graph of val_loss and train_loss over epochs
# plot the loss over epochs
plt.plot(model['history']['val_loss'], label='val_loss')
plt.plot(model['history']['train_loss'], label='train_loss')

# Add labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss over epochs | resnet18 | LR = 0.00015')
plt.legend()

# Display the plot
plt.show()
# Out:
# [147.52496234441207, 148.01301290221133, 147.94876072770458, 147.40668448755298, 147.5234375, 147.36079148114737, 147.17594961392678, 147.95302905066538, 147.24027071160785, 147.72686689991062, 147.0595656572762, 148.61801470740366, 147.82006396277475, 147.4587150185795, 147.4080435542737, 147.2360953638109, 147.48837875107589, 147.22095101566637, 147.50559997558594, 148.04398940781417, 147.47314698817365, 147.58971728308725, 147.35039313364837, 147.5277488837808, 148.1609550088139, 148.07230338403735, 147.842425071587, 148.66641080177436, 148.61017802610235, 148.88611499333786, 149.47177537821108, 152.23528328588452, 154.0250495005462, 157.03902551683328, 154.6835890947762, 156.7586623369637, 162.53179698879435, 161.80895659883143, 180.51984883971133, 169.72622473765227, 159.6786245572365, 162.19267247086864, 159.61373539294226, 162.55525517867784, 156.90483377747617, 156.95203399658203, 159.48734632589048, 155.91937669657045, 158.73365227650788, 156.04993658550714]
