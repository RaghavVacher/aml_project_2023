# %%
import torch
import matplotlib.pyplot as plt

# load a trained .pt file for analysis
model = torch.load('resnet101_LR0.001_SAMPLES_all_EPOCHS20_BATCHSIZE_64_TIME_2023-12-05_18:59:14.pt', map_location=torch.device('cpu'))
# print keys of model
print(model['history']['train_loss'])
print(model['history']['val_loss'])
#from model['history'] create a graph of val_loss and train_loss over epochs
# plot the loss over epochs
plt.plot(model['history']['train_loss'], label='train_loss')
plt.plot(model['history']['val_loss'], label='val_loss')


# Add labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss over epochs')
plt.legend()

# Display the plot
plt.show()
# Out:
# [141.44133418468718, 141.43055344439568, 141.4208335470646, 141.41806571635794, 141.4188907298636, 141.40983091313788, 141.40366489329236]
# [147.57042368049295, 147.54327901204428, 148.54485164544522, 147.95280143542166, 147.60792391524356, 148.03117135854868, 147.7448478111854]
